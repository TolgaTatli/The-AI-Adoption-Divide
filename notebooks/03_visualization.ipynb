# %%
import sys
sys.path.append('..')

from scripts.visualization import AIAdoptionVisualizer
import pandas as pd

# %% [markdown]
# ## 1. Visualizer'ı Başlat

# %%
viz = AIAdoptionVisualizer()

# %% [markdown]
# ## 2. Dünya Haritası - AI Adoption

# %%
world_map = viz.create_world_map()
world_map.show()

# %% [markdown]
# ## 3. GDP vs AI Interest Scatter Plot

# %%
scatter = viz.create_scatter_gdp_vs_ai()
scatter.show()

# %% [markdown]
# ## 4. Top 15 Ülke Bar Chart

# %%
bar_chart = viz.create_top_countries_bar(top_n=15)
bar_chart.show()

# %% [markdown]
# ## 5. Tüm Görselleştirmeleri Kaydet

# %%
viz.create_all_visualizations()

# %% [markdown]
# ## Sonuç
#
# Tüm görselleştirmeler `visualizations/` klasörüne kaydedildi.
# Bu dosyalar sunum ve poster için kullanılabilir!
